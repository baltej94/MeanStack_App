# %%
##################################################################################################
##################################################################################################


### This file and the source code provided can be used only for the projects and assignments  
### of this course

### Last Edit by Dr. Atef Bader: 7/13/2019


##################################################################################################

# %% [markdown]
# ## Divvy
#
# **Divvy** is a bicycle sharing system in the City of Chicago.
#
# Click __[here](https://en.wikipedia.org/wiki/Divvy)__ to read more about **Divvy**
#
#
# Click __[here](https://www.divvybikes.com/)__ to visit the official website for **Divvy**

# %% [markdown]
# This script will send a heartbeat every 2 minutes to divvy to collect their stations status in the City of Chicago.

# %% [markdown]
# ### PostgreSQL
#
# We will collect the data from **Divvy** servers and store the data in a table on **PostgreSQL** server.
#
# This python script will send a heartbeat to Divvy every 2 minutes to retrieve the status of the Divvy dock stations and store the data on PostgreSQL server.
#
# You need the package **psycopg2** to Connect to **PostgreSQL** server.
#
# Execute the **pip install** command from the command window to install  the package listed bove:
# - pip install psycopg2

# %%
import json
import requests
import datetime
import time
import os
import psycopg2
import pandas as pd
from urllib.request import urlopen
import json
import csv
from pprint import pprint
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT 
from datetime import datetime

# %%
from elasticsearch import Elasticsearch, helpers 

es = Elasticsearch()

# %%
def set_data(input_file, index_name = "divvy_station_logs", doc_type_name="log"):
    for line in input_file:
        
        yield {
            "_index": index_name,
            "_type": doc_type_name,
            "_source": line
            
        }

# %%
def load(es, input_file, **kwargs):
    success, _ = helpers.bulk(es, set_data(input_file, **kwargs))

# %%
# Get divvy statations status
# Status is returned as a json reply

# response = urlopen('https://feeds.divvybikes.com/stations/stations.json')

response_stations_info = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_information.json')
print('response_stations_info',response_stations_info)

response = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_status.json')
# Extract the body of the reply
response_body = response.read()
print(f'response_body = {response_body}\n\n')

response_stations_info = response_stations_info.read()
print(f'response_stations_info = {response_stations_info}')


# Decode the format in json format
stations_json = json.loads(response_body.decode("utf-8"))
stations_info_json = json.loads(response_stations_info.decode("utf-8"))
# Out:
# response_stations_info <http.client.HTTPResponse object at 0x000001A8E48ABFC8>
# response_body = b'{"last_updated":1584314555,"ttl":2,"data":{"stations":[{"station_id":"2","num_bikes_available":22,"num_ebikes_available":0,"num_bikes_disabled":0,"num_docks_available":17,"num_docks_disabled":0,"is_installed":1,"is_renting":1,"is_returning":1,"last_reported":1584313860,"eightd_has_available_keys":false},{"station_id":"3","num_bikes_available":8,"num_ebikes_available":0,"num_bikes_disabled":0,"num_docks_available":47,"num_docks_disabled":0,"is_installed":1,"is_renting":1,"is_returning":1,"last_reported":1584313588,"eightd_has_available_keys":false},{"station_id":"4","num_bikes_available":2,"num_ebikes_available":0,"num_bikes_disabled":0,"num_docks_available":21,"num_docks_disabled":0,"is_installed":1,"is_renting":1,"is_returning":1,"last_reported":1584313317,"eightd_has_available_keys":false},{"station_id":"5","num_bikes_available":18,"num_ebikes_available":0,"num_bikes_disabled":1,"num_docks_available":4,"num_docks_disabled":0,"is_installed":1,"is_renting":1,"is_returning":1,"last_reported":1584308886,"eightd_has_available_keys":false},{"station_id":"6","num_bikes_available":32,"num_ebikes_available":0,"num_bikes_disabled":1,"num_docks_available":6,"num_docks_disabled":0,"is_installed":1,"is_renting":1,"is_returning":1,"last_reported":1584313470,"eightd_has_available_keys":false},{"station_id":"7","num_bikes_available":17,"num_ebikes_available":0,"num_bikes_disabled":0,"num_docks_available":2,"num_docks_disabled":0,"is_installed":1,"is_renting":1,"is_returning":1,"last_reported":1584309115,"eightd_has_available_keys":false},{"station_id":"9","num_bikes_available":0,"num_ebikes_available":0,"num_bikes_disabled":0,"num_docks_available":15,"num_docks_disabled":0,"is_installed":1,"is_renting":1,"is_returning":1,"last_reported":1584247904,"eightd_has_available_keys":false},{"station_id":"11","num_bikes_available":1,"num_ebikes_available":0,"num_bikes_disabled":0,"num_docks_available":10,"num_docks_disabled":0,"is_installed":1,"is_renting":1,"is_returning":1,"last_reported":1584304289,"eightd_has_available_keys":false},{"station_id":"12","num_bikes_available":3,"num_ebikes_available":0,"num_bikes_disabled":0,"num_docks_available":12,"num_docks_disabled":0,"is_installed":1,"is_renting":1,"is_returning":1,"last_reported":1584312084,"eightd_has_available_keys":false},{"station_id":"13","num_bikes_available":18,"num_ebikes_available":0,"num_bikes_disabled":0,"num_docks_available":17,"num_docks_disabled":0,"is_installed":1,"is_renting":1,"is_returning":1,"last_reported":1584311073,"eightd_has_available_keys":false},{"station_id":"14","num_bikes_available":13,"num_ebikes_available":0,"num_bikes_disabled":0,"num_docks_available":2,"num_docks_disabled":0,"is_installed":1,"is_renting":1,"is_returning":1,"last_reported":1584312661,"eightd_has_available_keys":false},{"station_id":"15","num_bikes_available":5,"num_ebikes_available":0,"num_bikes_disabled":0,"num_docks_available":10,"num_docks_disabled":0,"is_installed":1,"is_renting":1,"is_returning":1,"last_reported":1584308673,"eightd_has_available_keys":false},{"station_id":"16","num_bikes_available":11,"num_ebikes_available":0,"num_bikes_disabled":0,"num_docks_available":4,"num_docks_disabled":0,"is_installed":1,"is_renting":1,"is_returning":1,"last_reported":1584313671,"eightd_has_available_keys":false},{"station_id":"17","num_bikes_available":12,"num_ebikes_available":0,"num_bikes_disabled":0,"num_docks_available":11,"num_docks_disabled":0,"is_installed":1,"is_renting":1,"is_returning":1,"last_reported":1584313241,"eightd_has_available_keys":false},{"station_id":"18","num_bikes_available":12,"num_ebikes_available":0,"num_bikes_disabled":0,"num_docks_available":7,"num_docks_disabled":0,"is_installed":1,"is_renting":1,"is_returning":1,"last_reported":1584311494,"eightd_has_available_keys":false},{"station_id":"19","num_bikes_available":1,"num_ebikes_available":0,"num_bikes_disabled":0,"num_docks_available":14,"num_docks_disabled":0,"is_installed":1,"is_renting":1,"is_return ...
#
#
# response_stations_info = b'{"last_updated":1584314553,"ttl":2,"data":{"stations":[{"station_id":"2","external_id":"a3a36d9e-a135-11e9-9cda-0a87ae2ba916","name":"Buckingham Fountain","short_name":"15541","lat":41.87651122881695,"lon":-87.62054800987242,"rental_methods":["TRANSITCARD","CREDITCARD","KEY"],"capacity":39,"electric_bike_surcharge_waiver":false,"eightd_has_key_dispenser":false,"has_kiosk":true},{"station_id":"3","external_id":"a3a37378-a135-11e9-9cda-0a87ae2ba916","name":"Shedd Aquarium","short_name":"15544","lat":41.86722595682,"lon":-87.6153553902,"rental_methods":["TRANSITCARD","CREDITCARD","KEY"],"capacity":55,"electric_bike_surcharge_waiver":false,"eightd_has_key_dispenser":false,"has_kiosk":true},{"station_id":"4","external_id":"a3a378ca-a135-11e9-9cda-0a87ae2ba916","name":"Burnham Harbor","short_name":"15545","lat":41.856268,"lon":-87.613348,"rental_methods":["TRANSITCARD","CREDITCARD","KEY"],"capacity":23,"electric_bike_surcharge_waiver":false,"eightd_has_key_dispenser":false,"has_kiosk":true},{"station_id":"5","external_id":"a3a37e26-a135-11e9-9cda-0a87ae2ba916","name":"State St & Harrison St","short_name":"SL-007","lat":41.874053,"lon":-87.627716,"rental_methods":["TRANSITCARD","CREDITCARD","KEY"],"capacity":23,"electric_bike_surcharge_waiver":false,"eightd_has_key_dispenser":false,"has_kiosk":true},{"station_id":"6","external_id":"a3a38363-a135-11e9-9cda-0a87ae2ba916","name":"Dusable Harbor","short_name":"KA1503000064","lat":41.886976,"lon":-87.612813,"rental_methods":["TRANSITCARD","CREDITCARD","KEY"],"capacity":39,"electric_bike_surcharge_waiver":false,"eightd_has_key_dispenser":false,"has_kiosk":true},{"station_id":"7","external_id":"a3a3888b-a135-11e9-9cda-0a87ae2ba916","name":"Field Blvd & South Water St","short_name":"15534","lat":41.88634906269,"lon":-87.6175165471,"rental_methods":["TRANSITCARD","CREDITCARD","KEY"],"capacity":19,"electric_bike_surcharge_waiver":false,"eightd_has_key_dispenser":false,"has_kiosk":true},{"station_id":"9","external_id":"a3a39301-a135-11e9-9cda-0a87ae2ba916","name":"Leavitt St & Archer Ave","short_name":"KA1503000068","lat":41.82879201994,"lon":-87.6806044594,"rental_methods":["TRANSITCARD","CREDITCARD","KEY"],"capacity":15,"electric_bike_surcharge_waiver":false,"eightd_has_key_dispenser":false,"has_kiosk":true},{"station_id":"11","external_id":"a3a3983e-a135-11e9-9cda-0a87ae2ba916","name":"Jeffery Blvd & 71st St","short_name":"KA1503000018","lat":41.76663823695,"lon":-87.5764501141,"rental_methods":["TRANSITCARD","CREDITCARD","KEY"],"capacity":11,"electric_bike_surcharge_waiver":false,"eightd_has_key_dispenser":false,"has_kiosk":true},{"station_id":"12","external_id":"a3a39d55-a135-11e9-9cda-0a87ae2ba916","name":"South Shore Dr & 71st St","short_name":"KA1503000002","lat":41.7664094567,"lon":-87.5656875719,"rental_methods":["TRANSITCARD","CREDITCARD","KEY"],"capacity":15,"electric_bike_surcharge_waiver":false,"eightd_has_key_dispenser":false,"has_kiosk":true},{"station_id":"13","external_id":"a3a3a282-a135-11e9-9cda-0a87ae2ba916","name":"Wilton Ave & Diversey Pkwy","short_name":"TA1306000014","lat":41.932418,"lon":-87.652705,"rental_methods":["TRANSITCARD","CREDITCARD","KEY"],"capacity":35,"electric_bike_surcharge_waiver":false,"eightd_has_key_dispenser":false,"has_kiosk":true},{"station_id":"14","external_id":"a3a3a7b4-a135-11e9-9cda-0a87ae2ba916","name":"Morgan St & 18th St","short_name":"13163","lat":41.858086,"lon":-87.651073,"rental_methods":["TRANSITCARD","CREDITCARD","KEY"],"capacity":15,"electric_bike_surcharge_waiver":false,"eightd_has_key_dispenser":false,"has_kiosk":true},{"station_id":"15","external_id":"a3a3ace6-a135-11e9-9cda-0a87ae2ba916","name":"Racine Ave & 18th St","short_name":"13164","lat":41.858166,"lon":-87.656495,"rental_methods":["TRANSITCARD","CREDITCARD","KEY"],"capacity":15,"electric_bike_surcharge_waiver":false,"eightd_has_key_dispenser":false,"has_kiosk":true},{"station_id":"16","external_id":"a3a3b202-a135-11e9-9cda-0a87ae2ba916","name":"P ...

# %%
pprint(stations_json)
# Out:
# {'data': {'stations': [{'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313860,
#                         'num_bikes_available': 22,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 17,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '2'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313588,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 47,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '3'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313317,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 21,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '4'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584308886,
#                         'num_bikes_available': 18,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '5'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313470,
#                         'num_bikes_available': 32,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '6'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584309115,
#                         'num_bikes_available': 17,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '7'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584247904,
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '9'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584304289,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '11'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584312084,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '12'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584311073,
#                         'num_bikes_available': 18,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 17,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '13'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584312661,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '14'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584308673,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '15'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313671,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '16'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313241,
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '17'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584311494,
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '18'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313783,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '19'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313184,
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '20'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584309156,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 16,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '21'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584311845,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '22'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313512,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '23'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313271,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '24'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314506,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '25'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314485,
#                         'num_bikes_available': 16,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '26'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584310535,
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '27'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314081,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '28'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584303728,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '29'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584308153,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '30'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314186,
#                         'num_bikes_available': 21,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '31'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584296195,
#                         'num_bikes_available': 16,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 3,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '32'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584308620,
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 18,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '33'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584265796,
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '34'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314232,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 2,
#                         'num_docks_available': 42,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '35'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313216,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 37,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '36'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313628,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '37'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584312777,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 23,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '38'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584309556,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 18,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '39'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584308040,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '40'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313577,
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '41'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584266107,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '42'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584312207,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 39,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '43'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584310838,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '44'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584312222,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '45'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584304712,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '46'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313761,
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 25,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '47'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313682,
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 34,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '48'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313089,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 28,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '49'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584298675,
#                         'num_bikes_available': 20,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '50'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313117,
#                         'num_bikes_available': 18,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 21,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '51'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584311945,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 33,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '52'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584312766,
#                         'num_bikes_available': 20,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '53'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313209,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '54'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313143,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 16,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '55'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314173,
#                         'num_bikes_available': 15,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '56'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313531,
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 3,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '57'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313767,
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 17,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '58'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584312303,
#                         'num_bikes_available': 15,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '59'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584312037,
#                         'num_bikes_available': 15,
#                         'num_bikes_disabled': 2,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '60'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314372,
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '61'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584309400,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 23,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '62'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314446,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 18,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '66'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313280,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 17,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '67'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584271433,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '68'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584311404,
#                         'num_bikes_available': 23,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 0,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '69'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314529,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '71'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584312242,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 31,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '72'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584309131,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '73'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584312154,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 16,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '74'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313411,
#                         'num_bikes_available': 29,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 18,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '75'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313867,
#                         'num_bikes_available': 15,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 23,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '76'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314133,
#                         'num_bikes_available': 16,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '77'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584310868,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '80'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314117,
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 33,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '81'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314220,
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '84'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584311092,
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '85'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314166,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '86'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584307622,
#                         'num_bikes_available': 16,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 3,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '87'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313998,
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '88'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584312230,
#                         'num_bikes_available': 22,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '89'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314016,
#                         'num_bikes_available': 25,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 21,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '90'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313936,
#                         'num_bikes_available': 17,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '91'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584299055,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 18,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '92'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584311503,
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 3,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '93'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584312908,
#                         'num_bikes_available': 24,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '94'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584308525,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '95'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584311209,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '96'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584305622,
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 47,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '97'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584312518,
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '98'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584312656,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '99'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584308328,
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 24,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '100'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584294982,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
# ...
#                         'is_returning': 1,
#                         'last_reported': 1584314257,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '640'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314330,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '641'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584179947,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '642'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314431,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '643'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314455,
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '644'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584297961,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '645'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584071793,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '646'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584265797,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '647'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1583643525,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '648'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314439,
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 1,
#                         'num_ebikes_available': 0,
#                         'station_id': '649'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584244635,
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '650'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1582260985,
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '651'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584179954,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '652'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584179954,
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '653'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314495,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '654'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584244704,
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '655'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314518,
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '656'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584313471,
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 3,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '657'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314427,
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '658'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584309953,
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '659'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584311859,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '660'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584219055,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '661'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584179957,
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '662'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584216955,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '663'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584314379,
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '664'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584179951,
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '665'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584297937,
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '666'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584312269,
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '672'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584312577,
#                         'num_bikes_available': 21,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '673'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1584179956,
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '675'}]},
#  'last_updated': 1584314555,
#  'ttl': 2}

# %%
pprint(stations_info_json)
# Out:
# {'data': {'stations': [{'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a36d9e-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87651122881695,
#                         'lon': -87.62054800987242,
#                         'name': 'Buckingham Fountain',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '15541',
#                         'station_id': '2'},
#                        {'capacity': 55,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a37378-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.86722595682,
#                         'lon': -87.6153553902,
#                         'name': 'Shedd Aquarium',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '15544',
#                         'station_id': '3'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a378ca-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.856268,
#                         'lon': -87.613348,
#                         'name': 'Burnham Harbor',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '15545',
#                         'station_id': '4'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a37e26-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.874053,
#                         'lon': -87.627716,
#                         'name': 'State St & Harrison St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'SL-007',
#                         'station_id': '5'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a38363-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.886976,
#                         'lon': -87.612813,
#                         'name': 'Dusable Harbor',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'KA1503000064',
#                         'station_id': '6'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3888b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.88634906269,
#                         'lon': -87.6175165471,
#                         'name': 'Field Blvd & South Water St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '15534',
#                         'station_id': '7'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a39301-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.82879201994,
#                         'lon': -87.6806044594,
#                         'name': 'Leavitt St & Archer Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'KA1503000068',
#                         'station_id': '9'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3983e-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.76663823695,
#                         'lon': -87.5764501141,
#                         'name': 'Jeffery Blvd & 71st St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'KA1503000018',
#                         'station_id': '11'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a39d55-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.7664094567,
#                         'lon': -87.5656875719,
#                         'name': 'South Shore Dr & 71st St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'KA1503000002',
#                         'station_id': '12'},
#                        {'capacity': 35,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3a282-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.932418,
#                         'lon': -87.652705,
#                         'name': 'Wilton Ave & Diversey Pkwy',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1306000014',
#                         'station_id': '13'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3a7b4-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.858086,
#                         'lon': -87.651073,
#                         'name': 'Morgan St & 18th St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13163',
#                         'station_id': '14'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3ace6-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.858166,
#                         'lon': -87.656495,
#                         'name': 'Racine Ave & 18th St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13164',
#                         'station_id': '15'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3b202-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.910337,
#                         'lon': -87.670072,
#                         'name': 'Paulina Ave & North Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000037',
#                         'station_id': '16'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3b731-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.903119,
#                         'lon': -87.673935,
#                         'name': 'Honore St & Division St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000034',
#                         'station_id': '17'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3bc53-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.883132,
#                         'lon': -87.637321,
#                         'name': 'Wacker Dr & Washington St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'KA1503000072',
#                         'station_id': '18'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3c174-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.868968,
#                         'lon': -87.659141,
#                         'name': 'Throop (Loomis) St & Taylor St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13139',
#                         'station_id': '19'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3c696-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.910522,
#                         'lon': -87.653106,
#                         'name': 'Sheffield Ave & Kingsbury St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13154',
#                         'station_id': '20'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3cbac-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87772613,
#                         'lon': -87.65478743,
#                         'name': 'Aberdeen St & Jackson Blvd',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13157',
#                         'station_id': '21'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3d1b8-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8694821,
#                         'lon': -87.6554864,
#                         'name': 'May St & Taylor St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13160',
#                         'station_id': '22'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3d6f0-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.902924,
#                         'lon': -87.637715,
#                         'name': 'Orleans St & Elm St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1306000006',
#                         'station_id': '23'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3dc37-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.89184737210993,
#                         'lon': -87.62058019638062,
#                         'name': 'Fairbanks Ct & Grand Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000003',
#                         'station_id': '24'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3e158-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.89766,
#                         'lon': -87.62351,
#                         'name': 'Michigan Ave & Pearson St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13034',
#                         'station_id': '25'},
#                        {'capacity': 31,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3e67b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.890359,
#                         'lon': -87.617532,
#                         'name': 'McClurg Ct & Illinois St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1306000013',
#                         'station_id': '26'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3eb9a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.91021,
#                         'lon': -87.6435,
#                         'name': 'Larrabee St & North Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1306000008',
#                         'station_id': '27'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3f0c6-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.91468,
#                         'lon': -87.64332,
#                         'name': 'Larrabee St & Menomonee St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1306000007',
#                         'station_id': '28'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3f5e9-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.90068,
#                         'lon': -87.6626,
#                         'name': 'Noble St & Milwaukee Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13290',
#                         'station_id': '29'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3fb5d-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.899643,
#                         'lon': -87.6677,
#                         'name': 'Ashland Ave & Augusta Blvd',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13248',
#                         'station_id': '30'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a40088-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.896746973093805,
#                         'lon': -87.63566762208939,
#                         'name': 'Franklin St & Chicago Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13017',
#                         'station_id': '31'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a405a1-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87464,
#                         'lon': -87.65703,
#                         'name': 'Racine Ave & Congress Pkwy',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1306000025',
#                         'station_id': '32'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a40ad8-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.877181,
#                         'lon': -87.627844,
#                         'name': 'State St & Van Buren St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000035',
#                         'station_id': '33'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a41004-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.9267559875,
#                         'lon': -87.6344287848,
#                         'name': 'Cannon Dr & Fullerton Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13124',
#                         'station_id': '34'},
#                        {'capacity': 47,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a41526-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.892278,
#                         'lon': -87.612043,
#                         'name': 'Streeter Dr & Grand Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13022',
#                         'station_id': '35'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a41af5-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8777079559,
#                         'lon': -87.6353211408,
#                         'name': 'Franklin St & Jackson Blvd',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000025',
#                         'station_id': '36'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4203a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8793563587,
#                         'lon': -87.6297910363,
#                         'name': 'Dearborn St & Adams St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000005',
#                         'station_id': '37'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a42574-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.88602082773,
#                         'lon': -87.6308760584,
#                         'name': 'Clark St & Lake St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'KA1503000012',
#                         'station_id': '38'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a42a93-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87947235235,
#                         'lon': -87.6256886059,
#                         'name': 'Wabash Ave & Adams St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'KA1503000015',
#                         'station_id': '39'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a42fa7-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87934437346,
#                         'lon': -87.6319852213,
#                         'name': 'LaSalle St & Adams St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'KA1503000034',
#                         'station_id': '40'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a434ce-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87207763285,
#                         'lon': -87.6295437729,
#                         'name': 'Federal St & Polk St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'SL-008',
#                         'station_id': '41'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a43a25-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.852619,
#                         'lon': -87.626488,
#                         'name': 'Wabash Ave & Cermak Rd',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000001',
#                         'station_id': '42'},
#                        {'capacity': 43,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a43f48-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8839840647265,
#                         'lon': -87.6246839761734,
#                         'name': 'Michigan Ave & Washington St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13001',
#                         'station_id': '43'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a44476-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8847302006,
#                         'lon': -87.6277335692,
#                         'name': 'State St & Randolph St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000029',
#                         'station_id': '44'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4499f-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.876243,
#                         'lon': -87.624426,
#                         'name': 'Michigan Ave & Ida B Wells Dr',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000010',
#                         'station_id': '45'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a44ec7-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.89993001,
#                         'lon': -87.63443007,
#                         'name': 'Wells St & Walton St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1306000011',
#                         'station_id': '46'},
#                        {'capacity': 31,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a453fa-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.889187,
#                         'lon': -87.627754,
#                         'name': 'State St & Kinzie St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13050',
#                         'station_id': '47'},
#                        {'capacity': 43,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4591a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.897764,
#                         'lon': -87.642884,
#                         'name': 'Larrabee St & Kingsbury St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1306000009',
#                         'station_id': '48'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a45e3b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.881319815,
#                         'lon': -87.6295209193,
#                         'name': 'Dearborn St & Monroe St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000006',
#                         'station_id': '49'},
#                        {'capacity': 35,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a46361-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8759326655,
#                         'lon': -87.6305845355,
#                         'name': 'Clark St & Ida B Wells Dr',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000009',
#                         'station_id': '50'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a46896-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.884576228,
#                         'lon': -87.63188991,
#                         'name': 'Clark St & Randolph St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000030',
#                         'station_id': '51'},
#                        {'capacity': 35,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a46e71-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.886024,
#                         'lon': -87.624117,
#                         'name': 'Michigan Ave & Lake St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000011',
#                         'station_id': '52'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4739d-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.894722,
#                         'lon': -87.634362,
#                         'name': 'Wells St & Huron St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1306000012',
#                         'station_id': '53'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a478c9-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.896362458,
#                         'lon': -87.6540612729,
#                         'name': 'Ogden Ave & Chicago Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000020',
#                         'station_id': '54'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a47dde-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.867324,
#                         'lon': -87.648625,
#                         'name': 'Halsted St & Roosevelt Rd',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000017',
#                         'station_id': '55'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a482fb-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.888716036,
#                         'lon': -87.6444478533,
#                         'name': 'Desplaines St & Kinzie St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1306000003',
#                         'station_id': '56'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4881d-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8671177825,
#                         'lon': -87.6410879593,
#                         'name': 'Clinton St & Roosevelt Rd',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'WL-008',
#                         'station_id': '57'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a48d5c-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.916017,
#                         'lon': -87.668879,
#                         'name': 'Marshfield Ave & Cortland St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000039',
#                         'station_id': '58'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a49288-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.867227,
#                         'lon': -87.625961,
#                         'name': 'Wabash Ave & Roosevelt Rd',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000002',
#                         'station_id': '59'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a497b6-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.9105780349,
#                         'lon': -87.6494219288,
#                         'name': 'Dayton St & North Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13058',
#                         'station_id': '60'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a49cd7-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.907655,
#                         'lon': -87.672552,
#                         'name': 'Wood St & Milwaukee Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13221',
#                         'station_id': '61'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4a202-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8513751729,
#                         'lon': -87.6188346489,
#                         'name': 'McCormick Place',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000004',
#                         'station_id': '62'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4a71e-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.885637,
#                         'lon': -87.641823,
#                         'name': 'Clinton St & Lake St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13021',
#                         'station_id': '66'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4ac3f-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.9256018819,
#                         'lon': -87.6537080423,
#                         'name': 'Sheffield Ave & Fullerton Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1306000016',
#                         'station_id': '67'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4b164-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.875885,
#                         'lon': -87.640795,
#                         'name': 'Clinton St & Tilden St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13037',
#                         'station_id': '68'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4b693-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.9093960065,
#                         'lon': -87.6776919292,
#                         'name': 'Damen Ave & Pierce Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000041',
#                         'station_id': '69'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4bbba-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8854833079,
#                         'lon': -87.6523048564,
#                         'name': 'Morgan St & Lake St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1306000015',
#                         'station_id': '71'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4c0df-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.860384,
#                         'lon': -87.625813,
#                         'name': 'Wabash Ave & 16th St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'SL-012',
#                         'station_id': '72'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4c618-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.880422,
#                         'lon': -87.642746,
#                         'name': 'Jefferson St & Monroe St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'WL-011',
#                         'station_id': '73'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4cb42-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.89380805624359,
#                         'lon': -87.64169722795485,
#                         'name': 'Kingsbury St & Erie St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13265',
#                         'station_id': '74'},
#                        {'capacity': 47,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4d069-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.877245,
#                         'lon': -87.639366,
#                         'name': 'Canal St & Jackson Blvd',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13138',
#                         'station_id': '75'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4d588-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.880958,
#                         'lon': -87.616743,
#                         'name': 'Lake Shore Dr & Monroe St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13300',
#                         'station_id': '76'},
#                        {'capacity': 31,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4daa1-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.882242,
#                         'lon': -87.641066,
#                         'name': 'Clinton St & Madison St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1305000032',
#                         'station_id': '77'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4e4e3-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.880419,
#                         'lon': -87.655519,
#                         'name': 'Aberdeen St & Monroe St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13156',
#                         'station_id': '80'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4ea00-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.884241,
#                         'lon': -87.629634,
#                         'name': 'Daley Center Plaza',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1306000010',
#                         'station_id': '81'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4ef26-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.891578,
#                         'lon': -87.648384,
#                         'name': 'Milwaukee Ave & Grand Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13033',
#                         'station_id': '84'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4f46b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.90096039,
#                         'lon': -87.62377664,
#                         'name': 'Michigan Ave & Oak St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13042',
#                         'station_id': '85'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4f993-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.89637337,
#                         'lon': -87.66098386,
#                         'name': 'Eckhart Park',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13289',
#                         'station_id': '86'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4fec3-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.92556258,
#                         'lon': -87.65840426,
#                         'name': 'Racine Ave & Fullerton Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'TA1306000026',
#                         'station_id': '87'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a503e5-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.884069,
#                         'lon': -87.656853,
#                         'name': 'Racine Ave & Randolph St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '13155',
#                         'station_id': '88'},
#                        {'capacity': 31,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a50991-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8750236280333,
#                         'lon': -87.6330940425396,
#                         'name': 'Financial Pl & Ida B Wells Dr',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'SL-010',
#                         'station_id': '89'},
#                        {'capacity': 47,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a50ec8-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8810317,
#                         'lon': -87.62408432,
#                         'name': 'Millennium Park',
# ...
#                         'short_name': '643',
#                         'station_id': '643'},
#                        {'capacity': 12,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b43eb7-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.868563,
#                         'lon': -87.686234,
#                         'name': 'Western Ave & Fillmore St (*)',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '644',
#                         'station_id': '644'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b443ce-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.826712,
#                         'lon': -87.683144,
#                         'name': 'Archer (Damen) Ave & 37th St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '18022',
#                         'station_id': '645'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4497a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.796642,
#                         'lon': -87.625923,
#                         'name': 'State St & 54th St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '646',
#                         'station_id': '646'},
#                        {'capacity': 7,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b44eba-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.786691,
#                         'lon': -87.655859,
#                         'name': 'Elizabeth St & 59th St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '647',
#                         'station_id': '647'},
#                        {'capacity': 7,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b453f2-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.77987,
#                         'lon': -87.650919,
#                         'name': 'Carpenter St & 63rd St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '18025',
#                         'station_id': '648'},
#                        {'capacity': 12,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4590f-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.779835,
#                         'lon': -87.634774,
#                         'name': 'Stewart Ave & 63rd St (*)',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '649',
#                         'station_id': '649'},
#                        {'capacity': 12,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b45e26-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.768898,
#                         'lon': -87.635876,
#                         'name': 'Eggleston Ave & 69th St (*)',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '650',
#                         'station_id': '650'},
#                        {'capacity': 7,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4633a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.765286,
#                         'lon': -87.621748,
#                         'name': 'Michigan Ave & 71st St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '651',
#                         'station_id': '651'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b46866-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.766,
#                         'lon': -87.611726,
#                         'name': 'Rhodes Ave & 71st St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '652',
#                         'station_id': '652'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b46d7b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.780595,
#                         'lon': -87.584846,
#                         'name': 'Cornell Dr & Hayes Dr',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '653',
#                         'station_id': '653'},
#                        {'capacity': 12,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4728f-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.883073,
#                         'lon': -87.656952,
#                         'name': 'Racine Ave & Washington Blvd (*)',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '654',
#                         'station_id': '654'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b477ac-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.979851,
#                         'lon': -87.681932,
#                         'name': 'Hoyne Ave & Balmoral Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '655',
#                         'station_id': '655'},
#                        {'capacity': 16,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b47cbc-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.885951,
#                         'lon': -87.677009,
#                         'name': 'Damen Ave & Walnut (Lake) St (*)',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'KA17018054',
#                         'station_id': '656'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b481e1-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.899181,
#                         'lon': -87.6722,
#                         'name': 'Wood St & Augusta Blvd',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '657',
#                         'station_id': '657'},
#                        {'capacity': 16,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b486f2-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.902997,
#                         'lon': -87.683825,
#                         'name': 'Leavitt St & Division St (*)',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '658',
#                         'station_id': '658'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b48c07-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.895501,
#                         'lon': -87.682017,
#                         'name': 'Leavitt St & Chicago Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '18058',
#                         'station_id': '659'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b49122-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 42.004583,
#                         'lon': -87.661406,
#                         'name': 'Sheridan Rd & Columbia Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '660',
#                         'station_id': '660'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4963f-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 42.057044,
#                         'lon': -87.686554,
#                         'name': 'Evanston Civic Center',
#                         'region_id': 35,
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '661',
#                         'station_id': '661'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b49b4c-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 42.023463,
#                         'lon': -87.699595,
#                         'name': 'Dodge Ave & Mulford St',
#                         'region_id': 35,
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '662',
#                         'station_id': '662'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4a05c-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 42.064854,
#                         'lon': -87.715297,
#                         'name': 'Lincolnwood Dr & Central St',
#                         'region_id': 35,
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'E014',
#                         'station_id': '663'},
#                        {'capacity': 16,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4a579-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.939354,
#                         'lon': -87.683282,
#                         'name': 'Leavitt St & Belmont Ave (*)',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'KA17018068',
#                         'station_id': '664'},
#                        {'capacity': 7,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4aa91-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.747363,
#                         'lon': -87.580046,
#                         'name': 'South Chicago Ave & Elliot Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '665',
#                         'station_id': '665'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3b4afb6-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.907221,
#                         'lon': -87.655618,
#                         'name': 'Cherry Ave & Blackhawk St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': '18069',
#                         'station_id': '666'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': '8995498f-1209-4b06-9317-01cd695b3b61',
#                         'has_kiosk': True,
#                         'lat': 41.89102331025185,
#                         'lon': -87.63547986745834,
#                         'name': 'Franklin St & Illinois St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'RN-',
#                         'station_id': '672'},
#                        {'capacity': 31,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': '9e1fbaaa-e872-4505-ada6-5080e62bef77',
#                         'has_kiosk': True,
#                         'lat': 41.92393131136619,
#                         'lon': -87.63582453131676,
#                         'name': 'Lincoln Park Conservatory',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'LP-',
#                         'station_id': '673'},
#                        {'capacity': 7,
#                         'eightd_has_key_dispenser': False,
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'ac61f1a4-1111-4b0e-8bb1-5b3833f5433a',
#                         'has_kiosk': True,
#                         'lat': 41.88991358344108,
#                         'lon': -87.68034316599368,
#                         'name': 'HQ QR',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'short_name': 'HQ QR',
#                         'station_id': '675'}]},
#  'last_updated': 1584314553,
#  'ttl': 2}

# %%
#Use default user name as postgres ,if username root is not working

db_connection = psycopg2.connect(host='127.0.0.1',dbname="postgres", user="postgres" , password="root")

# %%
db_connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT) 

cursor = db_connection.cursor()
print(cursor)
# Out:
# <cursor object at 0x000001A8E47ECF28; closed: 0>

# %%
    # Only once you need to create the postgis extension.
    # cursor.execute("CREATE DATABASE chicago_divvy_stations_status;")

db_connection = psycopg2.connect(host='127.0.0.1',dbname="chicago_divvy_stations_status", user="postgres" , password="root")


cursor = db_connection.cursor()

# %%
# Only once you need to create the postgis extension.
# Comment the following line if you already created the postgis extension
# Add it manually in Postgres ,if there is issue with this query

# cursor.execute("CREATE EXTENSION postgis;")

# %%
db_connection.commit()

# %%
cursor.execute("DROP TABLE IF EXISTS divvy_stations_realtime_status")

# %%
db_connection.commit()

# %%
cursor.execute("""CREATE TABLE divvy_stations_realtime_status(
                altitude FLOAT,
                availableBikes INTEGER,
                availableDocks INTEGER,
                city TEXT,
                id INTEGER,
                is_renting BOOLEAN,
                kioskType TEXT,
                landMark TEXT,
                lastCommunicationTime timestamp,
                latitude FLOAT,
                location TEXT,
                longitude FLOAT,
                postalCode INTEGER,
                stAddress1 TEXT,
                stAddress2 TEXT,
                stationName TEXT,
                status TEXT,
                statusKey INTEGER,
                statusValue TEXT,
                testStation BOOLEAN,
                totalDocks INTEGER,
                Where_is GEOGRAPHY);""")

# %%
db_connection.commit()

# %% [markdown]
# ### The following is the Heartbeat Loop - Pulls data from divvy every 2 minutes in order to get realtime updates for the different divvy stations

# %%
while True:
    # Get divvy statations status
    # Status is returned as a json reply

    response_stations_info = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_information.json')

    response = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_status.json')

    # Extract the body of the reply
    response_body = response.read()
    response_stations_info = response_stations_info.read()

    # Decode the format in json format
    stations_json = json.loads(response_body.decode("utf-8"))
    stations_info_json = json.loads(response_stations_info.decode("utf-8"))
    
    
    stations_dictionary = stations_json['data']
    stations_info_dictionary = stations_info_json['data']
    
    # load data file into a dataframe
    df__stations = pd.DataFrame(stations_dictionary['stations'])
    df__stations_info = pd.DataFrame(stations_info_dictionary['stations'])
    
    divvy_stations_realtime_status = pd.DataFrame(columns=[
                'altitude',
                'availableBikes',
                'availableDocks',
                'city',
                'id',
                'is_renting',
                'kioskType',
                'landMark',
                'lastCommunicationTime',
                'latitude',
                'location',
                'longitude',
                'postalCode',
                'stAddress1',
                'stAddress2',
                'stationName',
                'status',
                'statusKey',
                'statusValue',
                'testStation',
                'totalDocks' ])
    
    for x in range(len(df__stations.index)):
        has_kiosk = df__stations_info['has_kiosk'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0]
        row = [
            int(0),
            int(df__stations['num_bikes_available'].iloc[x]),
            int(df__stations['num_docks_available'].iloc[x]),
            'Chicago',
            int(df__stations['station_id'].iloc[x]),
            bool(df__stations['is_renting'].iloc[x]),
            has_kiosk,
            'Chicago',
            datetime.strptime(time.ctime(int(df__stations['last_reported'].iloc[x])), "%a %b %d %H:%M:%S %Y").strftime("%Y-%m-%d %H:%M:%S"),
            float(df__stations_info['lat'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0]),
            'Chicago',
            float(df__stations_info['lon'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0]),
            60602,
            'Chicago',
            'Chicago',
            df__stations_info['name'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0],
            'IN_SERVICE',
            1,
            'IN_SERVICE',
            False,
            int(df__stations_info['capacity'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0])]
    
        divvy_stations_realtime_status.loc[len(divvy_stations_realtime_status)] = row

        
    divvy_stations_realtime_status['altitude'] = divvy_stations_realtime_status['altitude'].astype(float)
    divvy_stations_realtime_status['availableBikes'] = divvy_stations_realtime_status['availableBikes'].astype(int)
    divvy_stations_realtime_status['availableDocks'] = divvy_stations_realtime_status['availableDocks'].astype(int)
    divvy_stations_realtime_status['city'] = divvy_stations_realtime_status.city.astype(str)
    divvy_stations_realtime_status['id'] = divvy_stations_realtime_status['id'].astype(int)
    divvy_stations_realtime_status['is_renting'] = divvy_stations_realtime_status['is_renting'].astype(bool)
    divvy_stations_realtime_status['kioskType'] = divvy_stations_realtime_status['kioskType'].astype(str)
    divvy_stations_realtime_status['landMark'] = divvy_stations_realtime_status['landMark'].astype(str)
    divvy_stations_realtime_status['lastCommunicationTime'] = divvy_stations_realtime_status['lastCommunicationTime'].astype(str)
    divvy_stations_realtime_status['latitude'] = divvy_stations_realtime_status['latitude'].astype(float)
    divvy_stations_realtime_status['location'] = divvy_stations_realtime_status['location'].astype(str)
    divvy_stations_realtime_status['longitude'] = divvy_stations_realtime_status['longitude'].astype(float)
    divvy_stations_realtime_status['postalCode'] = divvy_stations_realtime_status['postalCode'].astype(int)
    divvy_stations_realtime_status['stAddress1'] = divvy_stations_realtime_status['stAddress1'].astype(str)
    divvy_stations_realtime_status['stAddress2'] = divvy_stations_realtime_status['stAddress2'].astype(str)
    divvy_stations_realtime_status['stationName'] = divvy_stations_realtime_status['stationName'].astype(str)
    divvy_stations_realtime_status['status'] = divvy_stations_realtime_status['status'].astype(str)
    divvy_stations_realtime_status['statusKey'] = divvy_stations_realtime_status['statusKey'].astype(int)
    divvy_stations_realtime_status['statusValue'] = divvy_stations_realtime_status['statusValue'].astype(str)
    divvy_stations_realtime_status['testStation'] = divvy_stations_realtime_status['testStation'].astype(bool)
    divvy_stations_realtime_status['totalDocks'] = divvy_stations_realtime_status['totalDocks'].astype(int)
    
    # lets store our data subset into a file
    # This way you have a copy of data stored in a file 
    # that you could use in case you want to debug a problem on the orginal data received

    divvy_stations_realtime_status.to_csv('divvy_stations_status.csv',sep=',', encoding='utf-8', index=False)
    
    # delete existing data in the table
    cursor.execute("DELETE FROM divvy_stations_realtime_status")
    db_connection.commit()

    
    # Now we will connect to the database and store divvy data
    with open('divvy_stations_status.csv', 'r') as f:
        reader = csv.reader(f)
        next(reader)  # Skip the header row.
        for row in reader:
            cursor.execute( "INSERT INTO divvy_stations_realtime_status VALUES (%s, %s, %s, %s, %s,    %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,  %s, NULL)", row)

    
    
    db_connection.commit()
    
    cursor.execute("UPDATE divvy_stations_realtime_status SET Where_IS = ST_POINT(latitude,longitude);")
    db_connection.commit()
    
    
    # Now we will connect to ElasticSearch database and store divvy data
    divvy_stations_realtime_status = divvy_stations_realtime_status.to_json(orient='records')
    divvy_stations_realtime_status = json.loads(divvy_stations_realtime_status)
    load(es,divvy_stations_realtime_status)
    
    
    # Sleep for 3 minutes; divvy updates its stations status every 2 minutes
    now = datetime.now()
    timedate = ( (str(now.now())).split('.')[0]).split(' ')[0] + ' ' + ((str(now.now())).split('.')[0]).split(' ')[1]
 
    print(timedate, ' : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...')
    time.sleep(120)    
    continue

# %%
# close connection at the end of the script

db_connection.close()
